# %%
import os
import pandas as pd
from cleantext import clean
import json
import glob
from pprint import pprint
import datetime
import re  
import nltk  
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Cheng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
ethereum_path = "../Resources/ethereum.csv"

ethereum = pd.read_csv(ethereum_path)

ethereum.head(50)

# %%
df = ethereum.filter(['text','date'])[0:10000]

df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

# %%
cleantext=[]
for item in tqdm(df['text']):
    words=tweet_to_words(item)
    cleantext+=[words]
df['cleaned']=cleantext
df

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
def compute_vader_scores(df, label):
    sid = SentimentIntensityAnalyzer()
    df["negative"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neg"])
    df["neutral"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neu"])
    df["positive"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["pos"])
    df["comp"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["compound"])
    return df

# %%
final_ethereum = compute_vader_scores(df,'cleaned')
final_ethereum

# %%
# print(len(date), len(final_bitcoin.cleaned),len(final_bitcoin.negative),len(final_bitcoin.comp),len(final_bitcoin.neutral))

# %%
# final_bitcoin.isnull().values.any()

final_ethereum[['dates','Time']] = final_ethereum.date.str.split("+",expand=True)

final_ethereum

# %%
final_ethereum = final_ethereum.filter(['dates', 'cleaned','negative','neutral','positive','comp'])
final_ethereum.head(40)
# Out:
#                   dates                                            cleaned  \
# 0   2021-11-15 07:26:39  [get, upto, 1000, 10x, premium, spot, trade, s...
# 1   2021-11-15 07:26:35  [adopt, hypocat, 053, crazi, rich, cat, hypoca...
# 2   2021-11-15 07:26:32  [top, 10, coin, social, engag, last, 24, hr, l...
# 3   2021-11-15 07:26:30  [request, faucet, fund, 0x5278942b39ded8cbdad9...
# 4   2021-11-15 07:26:30  [new, list, bt, 0, 008eth, nft, nftcollector, ...
# 5   2021-11-15 07:25:51  [top, 10, coin, social, volum, last, 24, hr, l...
# 6   2021-11-15 07:25:39  [first, art, purchas, cutest, penguin, nft, ra...
# 7   2021-11-15 07:25:36  [mint, waterfal, graph, collect, http, co, wr0...
# 8   2021-11-15 07:25:25  [crypto, price, usd, bitcoin, 65710, 3048, eth...
# 9   2021-11-15 07:25:14  [cloud, mine, use, site, http, co, kgkt72uqa6,...
# 10  2021-11-15 07:25:08  [animoca, brand, unveil, plan, k, pop, nft, me...
# 11  2021-11-15 07:25:04  [request, faucet, fund, 0x174d78f4dacdc286fb54...
# 12  2021-11-15 07:24:57  [crypto, price, usd, bitcoin, 65707, 803, ethe...
# 13  2021-11-15 07:24:48  [michaeljburri, elonmusk, berniesand, bitcoin,...
# 14  2021-11-15 07:24:38  [tri, someth, new, nft, account, run, take, lo...
# 15  2021-11-15 07:24:36  [top, 10, coin, 3, month, twitter, volum, btc,...
# 16  2021-11-15 07:24:29  [mint, predatori, wolf, 124, collect, http, co...
# 17  2021-11-15 07:24:11  [request, faucet, fund, 0x67ccb9fb7d07dbc4118d...
# 18  2021-11-15 07:23:48  [elonmusk, everyon, invest, soon, bitcoin, eth...
# 19  2021-11-15 07:23:41             [current, ethereum, price, 4, 697, 90]
# 20  2021-11-15 07:23:38  [hero, motocorp, share, q2, result, buy, sell,...
# 21  2021-11-15 07:23:29  [hero, motocorp, share, q2, result, buy, sell,...
# 22  2021-11-15 07:23:19  [anoth, teaser, one, gener, nft, present, buu,...
# 23  2021-11-15 07:23:09  [win, amp, ltc, portfolio, would, get, sleeple...
# 24  2021-11-15 07:22:56  [today, crypto, currenc, top, 10, gainer, lose...
# 25  2021-11-15 07:22:53  [slow, 101, normal, 108, fast, 123, instant, 1...
# 26  2021-11-15 07:22:50  [bitcoin, shib, ethereum, tomcruis, know, part...
# 27  2021-11-15 07:22:48  [top, 10, cryptocurr, world, twitter, follow, ...
# 28  2021-11-15 07:22:36  [ok, 45k, usd, ape, project, pl, suggest, best...
# 29  2021-11-15 07:22:13  [mint, alo, collect, http, co, in9rfvbvdv, rar...
# 30  2021-11-15 07:22:02  [neighbor, alic, nft, fright, night, alic, far...
# 31  2021-11-15 07:21:45  [request, faucet, fund, 0x70783b552b9ecfee75b5...
# 32  2021-11-15 07:20:40  [etherbear, etherbear, ethereum, tothemoon, bu...
# 33  2021-11-15 07:20:09  [everyon, love, mxstoken, today, buy, 25billio...
# 34  2021-11-15 07:19:56  [0, 001, litecoin, ltc, crypto, mine, contract...
# 35  2021-11-15 07:19:39  [unpopular, opinion, real, money, made, invest...
# 36  2021-11-15 07:19:35  [etherbear, etherbear, ethereum, tothemoon, bu...
# 37  2021-11-15 07:19:30  [pl, retweet, mint, nft, filter, brain, collec...
# 38  2021-11-15 07:19:26  [strong, team, reliabl, idea, make, great, pro...
# 39  2021-11-15 07:19:22  [hope, sign, come, tri, quit, day, job, crypto...
#
#     negative  neutral  positive    comp
# 0      0.000    1.000     0.000  0.0000
# 1      0.000    0.813     0.187  0.6486
# 2      0.000    0.938     0.062  0.2023
# 3      0.000    1.000     0.000  0.0000
# 4      0.000    1.000     0.000  0.0000
# 5      0.000    0.938     0.062  0.2023
# 6      0.000    0.840     0.160  0.5859
# 7      0.000    1.000     0.000  0.0000
# 8      0.000    1.000     0.000  0.0000
# 9      0.000    1.000     0.000  0.0000
# 10     0.000    1.000     0.000  0.0000
# 11     0.000    1.000     0.000  0.0000
# 12     0.000    1.000     0.000  0.0000
# 13     0.000    1.000     0.000  0.0000
# 14     0.000    0.925     0.075  0.2960
# 15     0.000    0.942     0.058  0.2023
# 16     0.000    1.000     0.000  0.0000
# 17     0.000    1.000     0.000  0.0000
# 18     0.000    1.000     0.000  0.0000
# 19     0.000    1.000     0.000  0.0000
# 20     0.000    0.674     0.326  0.8910
# 21     0.000    0.674     0.326  0.8910
# 22     0.056    0.944     0.000 -0.2500
# 23     0.000    0.749     0.251  0.8658
# 24     0.097    0.852     0.051 -0.3818
# 25     0.084    0.916     0.000 -0.2732
# 26     0.000    0.711     0.289  0.7579
# 27     0.000    0.943     0.057  0.2023
# 28     0.000    0.670     0.330  0.7506
# 29     0.000    1.000     0.000  0.0000
# 30     0.075    0.925     0.000 -0.3818
# 31     0.000    1.000     0.000  0.0000
# 32     0.000    1.000     0.000  0.0000
# 33     0.000    0.764     0.236  0.8720
# 34     0.000    1.000     0.000  0.0000
# 35     0.000    1.000     0.000  0.0000
# 36     0.000    1.000     0.000  0.0000
# 37     0.000    1.000     0.000  0.0000
# 38     0.000    0.684     0.316  0.9022
# 39     0.000    0.854     0.146  0.4404

# %%
final_ethereum.to_csv('ethereum.csv')
