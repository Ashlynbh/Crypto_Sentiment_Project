# %%
import os
import pandas as pd
from cleantext import clean
import json
import glob
from pprint import pprint
import datetime
import re 
import glob
import nltk  
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Cheng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
eth_all_df = pd.read_csv("data/eth_day_1.csv",lineterminator='\n')
for i in range(1, 15):
    df = pd.read_csv(f"data/eth_day_{i}.csv",lineterminator='\n')
    eth_all_df = pd.concat([eth_all_df, df], axis=0)
    
eth_all_df.head()
# Out:
#    Unnamed: 0                   Datetime  \
# 0           0  2022-05-02 23:59:59+00:00
# 1           1  2022-05-02 23:59:45+00:00
# 2           2  2022-05-02 23:59:15+00:00
# 3           3  2022-05-02 23:59:12+00:00
# 4           4  2022-05-02 23:59:02+00:00
#
#                                               Text\r
# 0  【123战法早8点播报-2022.5.3】\n#BTC  日线：空，小时线：多\n#ETH ...
# 1  https://t.co/MeCEt7jfgS @DNC will be approving...
# 2  4 hour top movers report #blockchain #crypto #...
# 3  #Bitcoin Last Price $38512 #BTC 🚀\nDaily Indic...
# 4  $RickMortyDoxx $RMD #RMDOXX #ETH #Ethereum #Ai...

# %%
eth_all_df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#       Unnamed: 0                   Datetime  \
# 0              0  2022-05-02 23:59:59+00:00
# 1              1  2022-05-02 23:59:45+00:00
# 2              2  2022-05-02 23:59:15+00:00
# 3              3  2022-05-02 23:59:12+00:00
# 4              4  2022-05-02 23:59:02+00:00
# ...          ...                        ...
# 9996        9996  2022-05-15 05:41:39+00:00
# 9997        9997  2022-05-15 05:41:27+00:00
# 9998        9998  2022-05-15 05:41:14+00:00
# 9999        9999  2022-05-15 05:41:11+00:00
# 10000      10000  2022-05-15 05:41:05+00:00
#
#                                                   Text\r
# 0      1238-2022.5.3\n#BTC  \n#ETH       \nBTC38000ET...
# 1      https://t.co/MeCEt7jfgS @DNC will be approving...
# 2      4 hour top movers report #blockchain #crypto #...
# 3      #Bitcoin Last Price $38512 #BTC \nDaily Indica...
# 4      $RickMortyDoxx $RMD #RMDOXX #ETH #Ethereum #Ai...
# ...                                                  ...
# 9996   good morning to the crowd\n\n...and have a nic...
# 9997    Curated Coin Metrics every day \n\n#ETH  |  2...
# 9998   Paris No. 3  (1/1) .10eth\n\nI BELONG IN (TRAV...
# 9999   Woman by MaiPrisin\n\nhttps://t.co/GKcg5g6dwV\...
# 10000  #Bitcoin Last Price $29629 #BTC \nDaily Indica...
#
# [150015 rows x 3 columns]

# %%
eth_all_df.to_csv('data/eth_all.csv')

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

# %%
cleantext=[]
for item in tqdm(df['Text']):
    words=tweet_to_words(item)
    cleantext+=[words]
df['cleaned']=cleantext
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-9bcc446d2f85> in <module>
#       1 cleantext=[]
# ----> 2 for item in tqdm(df['Text']):
#       3     words=tweet_to_words(item)
#       4     cleantext+=[words]
#       5 df['cleaned']=cleantext
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Text'

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
def compute_vader_scores(df, label):
    sid = SentimentIntensityAnalyzer()
    df["negative"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neg"])
    df["neutral"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neu"])
    df["positive"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["pos"])
    df["comp"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["compound"])
    return df

# %%
final_bitcoin = compute_vader_scores(df,'cleaned')
final_bitcoin
# Out:
#        Unnamed: 0                   Datetime  \
# 0               0  2022-05-13 23:59:54+00:00
# 1               1  2022-05-13 23:59:54+00:00
# 2               2  2022-05-13 23:59:52+00:00
# 3               3  2022-05-13 23:59:51+00:00
# 4               4  2022-05-13 23:59:50+00:00
# ...           ...                        ...
# 9996         9996  2022-05-13 20:43:31+00:00
# 9997         9997  2022-05-13 20:43:31+00:00
# 9998         9998  2022-05-13 20:43:30+00:00
# 9999         9999  2022-05-13 20:43:29+00:00
# 10000       10000  2022-05-13 20:43:29+00:00
#
#                                                     Text  \
# 0      @BMC_NFT You love to see it! This project make...
# 1      @Bitcoin like i was fucking pissed of when the...
# 2      Baby bank is supporting those who are affected...
# 3      El Salvador y su apuesta por bitcoin lo puede ...
# 4      Dubai’s Emirates Airline Set to Embrace Bitcoi...
# ...                                                  ...
# 9996   @alexcloud2018 that being said, bitcoin doesn'...
# 9997   @nanoseagull @elonmusk @BillyM2k Doge is a Lit...
# 9998   THE RESPONSE 2 MY QLA VS BITCOIN CHALLENGE HAS...
# 9999   @PeterSchiff Here’s your chance to short Bitco...
# 10000  @bitcoin_dumpdog @AltCoinGirl_ @MulChainCapita...
#
#                                                  cleaned  negative  neutral  \
# 0      [bmc, nft, love, see, project, make, interest,...     0.000    0.585
# 1      [bitcoin, like, fuck, piss, price, go, realli,...     0.365    0.412
# 2      [babi, bank, support, affect, luna, crash, soo...     0.074    0.771
# 3      [el, salvador, su, apuesta, por, bitcoin, lo, ...     0.000    1.000
# 4      [dubai, emir, airlin, set, embrac, bitcoin, nf...     0.000    1.000
# ...                                                  ...       ...      ...
# 9996   [alexcloud2018, said, bitcoin, use, internet, ...     0.140    0.860
# 9997   [nanoseagul, elonmusk, billym2k, doge, litecoi...     0.000    0.896
# 9998   [respons, 2, qla, vs, bitcoin, challeng, bin, ...     0.274    0.671
# 9999   [peterschiff, chanc, short, bitcoin, peter, wa...     0.000    1.000
# 10000  [bitcoin, dumpdog, altcoingirl, mulchaincapit,...     0.089    0.780
#
#        positive    comp
# 0         0.415  0.9460
# 1         0.224 -0.5267
# 2         0.154  0.4404
# 3         0.000  0.0000
# 4         0.000  0.0000
# ...         ...     ...
# 9996      0.000 -0.3818
# 9997      0.104  0.2960
# 9998      0.054 -0.8798
# 9999      0.000  0.0000
# 10000     0.131  0.2960
#
# [10001 rows x 8 columns]

# %%
# print(len(date), len(final_bitcoin.cleaned),len(final_bitcoin.negative),len(final_bitcoin.comp),len(final_bitcoin.neutral))

# %%
# final_bitcoin.isnull().values.any()

final_bitcoin[['dates','Time']] = final_bitcoin.Datetime.str.split("+",expand=True)

final_bitcoin
# Out:
#        Unnamed: 0                   Datetime  \
# 0               0  2022-05-13 23:59:54+00:00
# 1               1  2022-05-13 23:59:54+00:00
# 2               2  2022-05-13 23:59:52+00:00
# 3               3  2022-05-13 23:59:51+00:00
# 4               4  2022-05-13 23:59:50+00:00
# ...           ...                        ...
# 9996         9996  2022-05-13 20:43:31+00:00
# 9997         9997  2022-05-13 20:43:31+00:00
# 9998         9998  2022-05-13 20:43:30+00:00
# 9999         9999  2022-05-13 20:43:29+00:00
# 10000       10000  2022-05-13 20:43:29+00:00
#
#                                                     Text  \
# 0      @BMC_NFT You love to see it! This project make...
# 1      @Bitcoin like i was fucking pissed of when the...
# 2      Baby bank is supporting those who are affected...
# 3      El Salvador y su apuesta por bitcoin lo puede ...
# 4      Dubai’s Emirates Airline Set to Embrace Bitcoi...
# ...                                                  ...
# 9996   @alexcloud2018 that being said, bitcoin doesn'...
# 9997   @nanoseagull @elonmusk @BillyM2k Doge is a Lit...
# 9998   THE RESPONSE 2 MY QLA VS BITCOIN CHALLENGE HAS...
# 9999   @PeterSchiff Here’s your chance to short Bitco...
# 10000  @bitcoin_dumpdog @AltCoinGirl_ @MulChainCapita...
#
#                                                  cleaned  negative  neutral  \
# 0      [bmc, nft, love, see, project, make, interest,...     0.000    0.585
# 1      [bitcoin, like, fuck, piss, price, go, realli,...     0.365    0.412
# 2      [babi, bank, support, affect, luna, crash, soo...     0.074    0.771
# 3      [el, salvador, su, apuesta, por, bitcoin, lo, ...     0.000    1.000
# 4      [dubai, emir, airlin, set, embrac, bitcoin, nf...     0.000    1.000
# ...                                                  ...       ...      ...
# 9996   [alexcloud2018, said, bitcoin, use, internet, ...     0.140    0.860
# 9997   [nanoseagul, elonmusk, billym2k, doge, litecoi...     0.000    0.896
# 9998   [respons, 2, qla, vs, bitcoin, challeng, bin, ...     0.274    0.671
# 9999   [peterschiff, chanc, short, bitcoin, peter, wa...     0.000    1.000
# 10000  [bitcoin, dumpdog, altcoingirl, mulchaincapit,...     0.089    0.780
#
#        positive    comp                dates   Time
# 0         0.415  0.9460  2022-05-13 23:59:54  00:00
# 1         0.224 -0.5267  2022-05-13 23:59:54  00:00
# 2         0.154  0.4404  2022-05-13 23:59:52  00:00
# 3         0.000  0.0000  2022-05-13 23:59:51  00:00
# 4         0.000  0.0000  2022-05-13 23:59:50  00:00
# ...         ...     ...                  ...    ...
# 9996      0.000 -0.3818  2022-05-13 20:43:31  00:00
# 9997      0.104  0.2960  2022-05-13 20:43:31  00:00
# 9998      0.054 -0.8798  2022-05-13 20:43:30  00:00
# 9999      0.000  0.0000  2022-05-13 20:43:29  00:00
# 10000     0.131  0.2960  2022-05-13 20:43:29  00:00
#
# [10001 rows x 10 columns]

# %%
final_bitcoin = final_bitcoin.filter(['dates', 'cleaned','negative','neutral','positive','comp'])
final_bitcoin.head(40)
# Out:
#                   dates                                            cleaned  \
# 0   2022-05-13 23:59:54  [bmc, nft, love, see, project, make, interest,...
# 1   2022-05-13 23:59:54  [bitcoin, like, fuck, piss, price, go, realli,...
# 2   2022-05-13 23:59:52  [babi, bank, support, affect, luna, crash, soo...
# 3   2022-05-13 23:59:51  [el, salvador, su, apuesta, por, bitcoin, lo, ...
# 4   2022-05-13 23:59:50  [dubai, emir, airlin, set, embrac, bitcoin, nf...
# 5   2022-05-13 23:59:49  [bitcoin, last, price, 29286, btc, daili, indi...
# 6   2022-05-13 23:59:47  [bitcoin, h, k, rd, luna, ld, di, erleri, de, ...
# 7   2022-05-13 23:59:46  [lunaticoin, rperezmarco, bitcoin, 2140, multi...
# 8   2022-05-13 23:59:46  [ayrastarr, vers, donjazzi, purchas, bitcoin, ...
# 9   2022-05-13 23:59:44  [hey, jackmal, love, built, strike, also, supp...
# 10  2022-05-13 23:59:43  [btc, bitcoin, btc, http, co, or6ws4k7cc, pink...
# 11  2022-05-13 23:59:42  [peterschiff, legit, question, happen, coin, r...
# 12  2022-05-13 23:59:41  [josevaldezsv, comparar, el, conflicto, de, la...
# 13  2022-05-13 23:59:40  [elgrandinero, goingparabol, peterschiff, hang...
# 14  2022-05-13 23:59:39         [brian, riedl, joebiden, 11, buy, bitcoin]
# 15  2022-05-13 23:59:37  [bitcoin, prepar, ndose, para, hacer, otro, en...
# 16  2022-05-13 23:59:37  [nayibbukel, faltan, 15, millon, listo, se, re...
# 17  2022-05-13 23:59:36  [bitcoin, ethereum, rough, week, deriv, data, ...
# 18  2022-05-13 23:59:35  [roadshow11235, tyotoriffl, broisthoma, jhgage...
# 19  2022-05-13 23:59:34  [452, btc, 13, 591, 794, usd, transfer, 3l2kga...
# 20  2022-05-13 23:59:34  [crypto, selloff, low, bitcoin, go, http, co, ...
# 21  2022-05-13 23:59:34  [claim, free, lightn, sat, bitcoin, zesti, fau...
# 22  2022-05-13 23:59:32  [bitcoin, price, index, http, co, o7uchjuhc6, ...
# 23  2022-05-13 23:59:32  [excelent, fin, de, semana, bitcoin, blockchai...
# 24  2022-05-13 23:59:32  [updat, bitcoin, transact, fee, bch, next, blo...
# 25  2022-05-13 23:59:31  [guy, go, check, bitrefil, gift, card, need, h...
# 26  2022-05-13 23:59:30  [thank, bitrefil, sponsor, huntsvillebtc, meet...
# 27  2022-05-13 23:59:29  [bitcoin, price, ralli, 20, market, rout, http...
# 28  2022-05-13 23:59:28  [justinbracy2, ye, take, bitcoin, car, one, po...
# 29  2022-05-13 23:59:24  [ditado, que, se, tornaram, mentira, ness, lti...
# 30  2022-05-13 23:59:23  [vailshirecap, complet, differ, crypto, fiat, ...
# 31  2022-05-13 23:59:23                  [ghostvirusx, noth, bitcoin, tho]
# 32  2022-05-13 23:59:20  [perdi, td, com, meu, aluno, chamando, bitcoin...
# 33  2022-05-13 23:59:18  [esamismachera, en, bitcoin, cuanto, vien, sie...
# 34  2022-05-13 23:59:17  [ericwil06256732, jhgage1, andrew, civil, gera...
# 35  2022-05-13 23:59:16  [dubai, emir, airlin, set, embrac, bitcoin, nf...
# 36  2022-05-13 23:59:14  [4, hour, top, mover, report, blockchain, cryp...
# 37  2022-05-13 23:59:13  [joshtpm, accept, bitcoin, payment, car, bough...
# 38  2022-05-13 23:59:12                                      [fx, bitcoin]
# 39  2022-05-13 23:59:12  [bitcoin, 200, wma, keep, grind, upward, almos...
#
#     negative  neutral  positive    comp
# 0      0.000    0.585     0.415  0.9460
# 1      0.365    0.412     0.224 -0.5267
# 2      0.074    0.771     0.154  0.4404
# 3      0.000    1.000     0.000  0.0000
# 4      0.000    1.000     0.000  0.0000
# 5      0.055    0.945     0.000 -0.2960
# 6      0.000    1.000     0.000  0.0000
# 7      0.000    1.000     0.000  0.0000
# 8      0.000    1.000     0.000  0.0000
# 9      0.077    0.567     0.356  0.7506
# 10     0.165    0.691     0.144 -0.1027
# 11     0.000    0.712     0.288  0.8074
# 12     0.000    1.000     0.000  0.0000
# 13     0.000    1.000     0.000  0.0000
# 14     0.000    1.000     0.000  0.0000
# 15     0.000    1.000     0.000  0.0000
# 16     0.000    1.000     0.000  0.0000
# 17     0.000    1.000     0.000  0.0000
# 18     0.000    1.000     0.000  0.0000
# 19     0.000    0.848     0.152  0.3612
# 20     0.231    0.769     0.000 -0.2732
# 21     0.000    0.864     0.136  0.5106
# 22     0.000    1.000     0.000  0.0000
# 23     0.000    0.820     0.180  0.2960
# 24     0.244    0.756     0.000 -0.7003
# 25     0.000    0.682     0.318  0.6808
# 26     0.090    0.664     0.246  0.5106
# 27     0.000    1.000     0.000  0.0000
# 28     0.000    1.000     0.000  0.0000
# 29     0.000    1.000     0.000  0.0000
# 30     0.000    1.000     0.000  0.0000
# 31     0.000    1.000     0.000  0.0000
# 32     0.000    1.000     0.000  0.0000
# 33     0.000    1.000     0.000  0.0000
# 34     0.000    1.000     0.000  0.0000
# 35     0.000    1.000     0.000  0.0000
# 36     0.000    0.913     0.087  0.2023
# 37     0.145    0.692     0.164  0.0772
# 38     0.000    1.000     0.000  0.0000
# 39     0.000    1.000     0.000  0.0000

# %%
final_ethereum.to_csv('ethereum.csv')
