# %%
import os
import pandas as pd
from cleantext import clean
import json
import glob
from pprint import pprint
import datetime
import re  
import nltk  
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ashlyn/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
doge_path = "../Data/dollar_doge_combined.csv"

doge = pd.read_csv(doge_path)

doge.head(50)
# Out:
#     Unnamed: 0  Unnamed: 0.1                   Datetime  \
# 0            0             0  2022-05-01 23:59:29+00:00
# 1            1             1  2022-05-01 23:59:17+00:00
# 2            2             2  2022-05-01 23:58:02+00:00
# 3            3             3  2022-05-01 23:57:42+00:00
# 4            4             4  2022-05-01 23:56:17+00:00
# 5            5             5  2022-05-01 23:55:52+00:00
# 6            6             6  2022-05-01 23:55:01+00:00
# 7            7             7  2022-05-01 23:54:42+00:00
# 8            8             8  2022-05-01 23:53:42+00:00
# 9            9             9  2022-05-01 23:53:21+00:00
# 10          10            10  2022-05-01 23:53:01+00:00
# 11          11            11  2022-05-01 23:52:12+00:00
# 12          12            12  2022-05-01 23:52:03+00:00
# 13          13            13  2022-05-01 23:51:38+00:00
# 14          14            14  2022-05-01 23:51:28+00:00
# 15          15            15  2022-05-01 23:51:27+00:00
# 16          16            16  2022-05-01 23:49:44+00:00
# 17          17            17  2022-05-01 23:48:27+00:00
# 18          18            18  2022-05-01 23:45:24+00:00
# 19          19            19  2022-05-01 23:41:05+00:00
# 20          20            20  2022-05-01 23:41:02+00:00
# 21          21            21  2022-05-01 23:40:44+00:00
# 22          22            22  2022-05-01 23:40:40+00:00
# 23          23            23  2022-05-01 23:39:57+00:00
# 24          24            24  2022-05-01 23:39:13+00:00
# 25          25            25  2022-05-01 23:38:12+00:00
# 26          26            26  2022-05-01 23:37:52+00:00
# 27          27            27  2022-05-01 23:34:22+00:00
# 28          28            28  2022-05-01 23:34:04+00:00
# 29          29            29  2022-05-01 23:32:12+00:00
# 30          30            30  2022-05-01 23:31:22+00:00
# 31          31            31  2022-05-01 23:29:33+00:00
# 32          32            32  2022-05-01 23:28:31+00:00
# 33          33            33  2022-05-01 23:28:26+00:00
# 34          34            34  2022-05-01 23:27:27+00:00
# 35          35            35  2022-05-01 23:27:00+00:00
# 36          36            36  2022-05-01 23:25:07+00:00
# 37          37            37  2022-05-01 23:23:12+00:00
# 38          38            38  2022-05-01 23:22:08+00:00
# 39          39            39  2022-05-01 23:22:03+00:00
# 40          40            40  2022-05-01 23:20:27+00:00
# 41          41            41  2022-05-01 23:20:09+00:00
# 42          42            42  2022-05-01 23:19:55+00:00
# 43          43            43  2022-05-01 23:19:15+00:00
# 44          44            44  2022-05-01 23:17:58+00:00
# 45          45            45  2022-05-01 23:16:34+00:00
# 46          46            46  2022-05-01 23:11:37+00:00
# 47          47            47  2022-05-01 23:11:11+00:00
# 48          48            48  2022-05-01 23:11:08+00:00
# 49          49            49  2022-05-01 23:08:42+00:00
#
#                                                  Text
# 0   $BTC $ETH $DOGE $ens    Best discord community...
# 1   @selenaroyf @PolyDoge @MetaPetzAI @JamieBa0632...
# 2   ツイート数の多かった仮想通貨\n1位 $ETH 1429 Tweets\n2位 $BTC 1...
# 3   @selenaroyf @PolyDoge @MetaPetzAI @Carpenterrr...
# 4   $264,600,000,000 x 7.55 = 1,997,730,000,000 $D...
# 5   Looking for a low cap 💎? Under 1M Marketcap?  ...
# 6   "The market has failed to price in the possibi...
# 7   @selenaroyf @PolyDoge @MetaPetzAI Big project ...
# 8   @Bitso @elonmusk @Dogecoin\nCon este mercado b...
# 9   @selenaroyf @PolyDoge @MetaPetzAI @Pruittee407...
# 10         1 USD = 7.55 $DOGE https://t.co/hALfLKKDCi
# 11  In 2018, #bitcoin went from $19,666 down to $3...
# 12  Dogecoin DOGE Current Price:\n$0.1327\n\n1h: +...
# 13  Support us on patreon! https://t.co/ftiSeylK1m...
# 14  @elonmusk @BillyM2k Will @dogecoin be a part o...
# 15  @selenaroyf @PolyDoge @MetaPetzAI @PaulaHa1118...
# 16  @sadiesupafly @ronereynolds @Dogepalooza @Doge...
# 17  No. \n\n $38,335,200 worth of $DOGE sent in th...
# 18  @sadiesupafly @ronereynolds @Dogepalooza @Doge...
# 19  @selenaroyf @PolyDoge @MetaPetzAI @Escobarbb37...
# 20  Take us to the 🌒🌌\n\n#dogecoin $doge #dogearmy...
# 21  The current price of one DOGE is now: $0.1332,...
# 22  @Unofficialterry @okaydoge @elonmusk @dogecoin...
# 23  @raqueti21 @okaydoge @elonmusk @dogecoin @Magi...
# 24  @okaydoge @giseller88 @elonmusk @dogecoin @Mag...
# 25    @gate_io Yes it will be a good result for $DOGE
# 26  @victorydrop @okaydoge @elonmusk @dogecoin @Ma...
# 27                      $doge https://t.co/gxLFwTydcC
# 28  Man, if I had a $DOGE coin for every random cr...
# 29  @itsALLrisky While there are other dogs in the...
# 30  $DOGE dance......                             ...
# 31  @FarzadAhangi @elonmusk @dogecoin @TDogewhispe...
# 32  @VitaInuCoinPT @BitMartExchange @BinancePT @Vi...
# 33  $DOGE                                         ...
# 34  @sadiesupafly @ronereynolds @Dogepalooza @Doge...
# 35  @Dogememegirl @dogecoin If you know how, you c...
# 36                     Gw Dejavu $DOGE naik ke IDR 8K
# 37  the next $KIBA $MRI $DOGE has arrived. and it ...
# 38  1B🐂Bull Cryptos In The Past 7 Days\nSymbol, %$...
# 39  $BTC: 38411.257 (1.53%)\n$ETH: 2816.783 (2.72%...
# 40  @CryptoInsightsX @dogecoin @Shibtoken @Dogelon...
# 41  @Cryptoscreen_en @Cryptotech_Ann @verasitytech...
# 42  20 bin tl ile 10.000 $doge #doge aldım bugün m...
# 43  #doge at the edge. If it break down the trendl...
# 44  🔴 2013 - You missed $BTC\n🔴 2014 - You missed ...
# 45  The true value of #Dogecoin is clear in this p...
# 46  Forget Lambos, this is what my heart desires.\...
# 47  @DogecoinRide Flipping for $FLOKI. The upside ...
# 48  @elonmusk @tesla @dogecoin @BillyM2k @MattWall...
# 49  @BitcoinMagazine Depends on the network. 6 min...

# %%
df = doge.filter(['Text','Datetime'])

df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                                                     Text  \
# 0      $BTC $ETH $DOGE $ens    Best discord community...
# 1      @selenaroyf @PolyDoge @MetaPetzAI @JamieBa0632...
# 2      \n1 $ETH 1429 Tweets\n2 $BTC 1033 Tweets\n3 $U...
# 3      @selenaroyf @PolyDoge @MetaPetzAI @Carpenterrr...
# 4      $264,600,000,000 x 7.55 = 1,997,730,000,000 $D...
# ...                                                  ...
# 34403   Prices update in $USD | Last 1 hour\n\n$XRP :...
# 34404   $BTC: 29240.80 USD\n $ETH: 2006.14 USD\n $BNB...
# 34405  $BTC Price: $29,311 \n$ETH Price: $2,013.62 \n...
# 34406   Compra #BabyDoge y otras #memecoins en #OKX! ...
# 34407   Compre #BabyDoge e outras #memecoins na #OKX!...
#
#                         Datetime
# 0      2022-05-01 23:59:29+00:00
# 1      2022-05-01 23:59:17+00:00
# 2      2022-05-01 23:58:02+00:00
# 3      2022-05-01 23:57:42+00:00
# 4      2022-05-01 23:56:17+00:00
# ...                          ...
# 34403  2022-05-14 00:00:04+00:00
# 34404  2022-05-14 00:00:04+00:00
# 34405  2022-05-14 00:00:01+00:00
# 34406  2022-05-14 00:00:00+00:00
# 34407  2022-05-14 00:00:00+00:00
#
# [34408 rows x 2 columns]

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

# %%
cleantext=[]
for item in tqdm(df['Text']):
    words=tweet_to_words(item)
    cleantext+=[words]
df['cleaned']=cleantext
df
# Out:
# 100%|█████████████████████████████████████| 34408/34408 [06:53<00:00, 83.21it/s]
#                                                     Text  \
# 0      $BTC $ETH $DOGE $ens    Best discord community...
# 1      @selenaroyf @PolyDoge @MetaPetzAI @JamieBa0632...
# 2      ツイート数の多かった仮想通貨\n1位 $ETH 1429 Tweets\n2位 $BTC 1...
# 3      @selenaroyf @PolyDoge @MetaPetzAI @Carpenterrr...
# 4      $264,600,000,000 x 7.55 = 1,997,730,000,000 $D...
# ...                                                  ...
# 34403  🔄 Prices update in $USD | Last 1 hour\n\n$XRP ...
# 34404  🟩 $BTC: 29240.80 USD\n🟩 $ETH: 2006.14 USD\n🟩 $...
# 34405  $BTC Price: $29,311 📉\n$ETH Price: $2,013.62 📉...
# 34406  📈 ¡Compra #BabyDoge y otras #memecoins en #OKX...
# 34407  📈 Compre #BabyDoge e outras #memecoins na #OKX...
#
#                         Datetime  \
# 0      2022-05-01 23:59:29+00:00
# 1      2022-05-01 23:59:17+00:00
# 2      2022-05-01 23:58:02+00:00
# 3      2022-05-01 23:57:42+00:00
# 4      2022-05-01 23:56:17+00:00
# ...                          ...
# 34403  2022-05-14 00:00:04+00:00
# 34404  2022-05-14 00:00:04+00:00
# 34405  2022-05-14 00:00:01+00:00
# 34406  2022-05-14 00:00:00+00:00
# 34407  2022-05-14 00:00:00+00:00
#
#                                                  cleaned
# 0      [btc, eth, doge, en, best, discord, commun, fa...
# 1      [selenaroyf, polydog, metapetzai, jamieba06321...
# 2      [1, eth, 1429, tweet, 2, btc, 1033, tweet, 3, ...
# 3      [selenaroyf, polydog, metapetzai, carpenterrr4...
# 4      [264, 600, 000, 000, x, 7, 55, 1, 997, 730, 00...
# ...                                                  ...
# 34403  [price, updat, usd, last, 1, hour, xrp, 0, 42,...
# 34404  [btc, 29240, 80, usd, eth, 2006, 14, usd, bnb,...
# 34405  [btc, price, 29, 311, eth, price, 2, 013, 62, ...
# 34406  [compra, babydog, otra, memecoin, en, okx, bab...
# 34407  [compr, babydog, e, outra, memecoin, na, okx, ...
#
# [34408 rows x 3 columns]

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
def compute_vader_scores(df, label):
    sid = SentimentIntensityAnalyzer()
    df["negative"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neg"])
    df["neutral"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neu"])
    df["positive"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["pos"])
    df["comp"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["compound"])
    return df

# %%
final_doge = compute_vader_scores(df,'cleaned')
final_doge
# Out:
#                                                     Text  \
# 0      $BTC $ETH $DOGE $ens    Best discord community...
# 1      @selenaroyf @PolyDoge @MetaPetzAI @JamieBa0632...
# 2      ツイート数の多かった仮想通貨\n1位 $ETH 1429 Tweets\n2位 $BTC 1...
# 3      @selenaroyf @PolyDoge @MetaPetzAI @Carpenterrr...
# 4      $264,600,000,000 x 7.55 = 1,997,730,000,000 $D...
# ...                                                  ...
# 34403  🔄 Prices update in $USD | Last 1 hour\n\n$XRP ...
# 34404  🟩 $BTC: 29240.80 USD\n🟩 $ETH: 2006.14 USD\n🟩 $...
# 34405  $BTC Price: $29,311 📉\n$ETH Price: $2,013.62 📉...
# 34406  📈 ¡Compra #BabyDoge y otras #memecoins en #OKX...
# 34407  📈 Compre #BabyDoge e outras #memecoins na #OKX...
#
#                         Datetime  \
# 0      2022-05-01 23:59:29+00:00
# 1      2022-05-01 23:59:17+00:00
# 2      2022-05-01 23:58:02+00:00
# 3      2022-05-01 23:57:42+00:00
# 4      2022-05-01 23:56:17+00:00
# ...                          ...
# 34403  2022-05-14 00:00:04+00:00
# 34404  2022-05-14 00:00:04+00:00
# 34405  2022-05-14 00:00:01+00:00
# 34406  2022-05-14 00:00:00+00:00
# 34407  2022-05-14 00:00:00+00:00
#
#                                                  cleaned  negative  neutral  \
# 0      [btc, eth, doge, en, best, discord, commun, fa...     0.078    0.578
# 1      [selenaroyf, polydog, metapetzai, jamieba06321...     0.000    1.000
# 2      [1, eth, 1429, tweet, 2, btc, 1033, tweet, 3, ...     0.000    1.000
# 3      [selenaroyf, polydog, metapetzai, carpenterrr4...     0.000    1.000
# 4      [264, 600, 000, 000, x, 7, 55, 1, 997, 730, 00...     0.000    1.000
# ...                                                  ...       ...      ...
# 34403  [price, updat, usd, last, 1, hour, xrp, 0, 42,...     0.000    1.000
# 34404  [btc, 29240, 80, usd, eth, 2006, 14, usd, bnb,...     0.000    1.000
# 34405  [btc, price, 29, 311, eth, price, 2, 013, 62, ...     0.000    1.000
# 34406  [compra, babydog, otra, memecoin, en, okx, bab...     0.000    1.000
# 34407  [compr, babydog, e, outra, memecoin, na, okx, ...     0.000    1.000
#
#        positive    comp
# 0         0.344  0.8481
# 1         0.000  0.0000
# 2         0.000  0.0000
# 3         0.000  0.0000
# 4         0.000  0.0000
# ...         ...     ...
# 34403     0.000  0.0000
# 34404     0.000  0.0000
# 34405     0.000  0.0000
# 34406     0.000  0.0000
# 34407     0.000  0.0000
#
# [34408 rows x 7 columns]

# %%
# print(len(date), len(final_bitcoin.cleaned),len(final_bitcoin.negative),len(final_bitcoin.comp),len(final_bitcoin.neutral))

# %%
# final_bitcoin.isnull().values.any()

final_doge[['Datetime','Text']] = final_doge.Datetime.str.split("+",expand=True)

final_doge
# Out:
#         Text             Datetime  \
# 0      00:00  2022-05-01 23:59:29
# 1      00:00  2022-05-01 23:59:17
# 2      00:00  2022-05-01 23:58:02
# 3      00:00  2022-05-01 23:57:42
# 4      00:00  2022-05-01 23:56:17
# ...      ...                  ...
# 34403  00:00  2022-05-14 00:00:04
# 34404  00:00  2022-05-14 00:00:04
# 34405  00:00  2022-05-14 00:00:01
# 34406  00:00  2022-05-14 00:00:00
# 34407  00:00  2022-05-14 00:00:00
#
#                                                  cleaned  negative  neutral  \
# 0      [btc, eth, doge, en, best, discord, commun, fa...     0.078    0.578
# 1      [selenaroyf, polydog, metapetzai, jamieba06321...     0.000    1.000
# 2      [1, eth, 1429, tweet, 2, btc, 1033, tweet, 3, ...     0.000    1.000
# 3      [selenaroyf, polydog, metapetzai, carpenterrr4...     0.000    1.000
# 4      [264, 600, 000, 000, x, 7, 55, 1, 997, 730, 00...     0.000    1.000
# ...                                                  ...       ...      ...
# 34403  [price, updat, usd, last, 1, hour, xrp, 0, 42,...     0.000    1.000
# 34404  [btc, 29240, 80, usd, eth, 2006, 14, usd, bnb,...     0.000    1.000
# 34405  [btc, price, 29, 311, eth, price, 2, 013, 62, ...     0.000    1.000
# 34406  [compra, babydog, otra, memecoin, en, okx, bab...     0.000    1.000
# 34407  [compr, babydog, e, outra, memecoin, na, okx, ...     0.000    1.000
#
#        positive    comp
# 0         0.344  0.8481
# 1         0.000  0.0000
# 2         0.000  0.0000
# 3         0.000  0.0000
# 4         0.000  0.0000
# ...         ...     ...
# 34403     0.000  0.0000
# 34404     0.000  0.0000
# 34405     0.000  0.0000
# 34406     0.000  0.0000
# 34407     0.000  0.0000
#
# [34408 rows x 7 columns]

# %%
final_doge = final_doge.filter(['Datetime', 'cleaned','negative','neutral','positive','comp'])
final_doge.head(40)
# Out:
#                Datetime                                            cleaned  \
# 0   2022-05-01 23:59:29  [btc, eth, doge, en, best, discord, commun, fa...
# 1   2022-05-01 23:59:17  [selenaroyf, polydog, metapetzai, jamieba06321...
# 2   2022-05-01 23:58:02  [1, eth, 1429, tweet, 2, btc, 1033, tweet, 3, ...
# 3   2022-05-01 23:57:42  [selenaroyf, polydog, metapetzai, carpenterrr4...
# 4   2022-05-01 23:56:17  [264, 600, 000, 000, x, 7, 55, 1, 997, 730, 00...
# 5   2022-05-01 23:55:52  [look, low, cap, 1m, marketcap, 10m, suppli, h...
# 6   2022-05-01 23:55:01  [market, fail, price, possibl, daddi, elon, cu...
# 7   2022-05-01 23:54:42  [selenaroyf, polydog, metapetzai, big, project...
# 8   2022-05-01 23:53:42  [bitso, elonmusk, dogecoin, con, est, mercado,...
# 9   2022-05-01 23:53:21  [selenaroyf, polydog, metapetzai, pruittee4071...
# 10  2022-05-01 23:53:01        [1, usd, 7, 55, doge, http, co, halflkkdci]
# 11  2022-05-01 23:52:12  [2018, bitcoin, went, 19, 666, 3, 181, 83, 8, ...
# 12  2022-05-01 23:52:03  [dogecoin, doge, current, price, 0, 1327, 1h, ...
# 13  2022-05-01 23:51:38  [support, us, patreon, http, co, ftiseylk1m, e...
# 14  2022-05-01 23:51:28  [elonmusk, billym2k, dogecoin, part, vision, f...
# 15  2022-05-01 23:51:27  [selenaroyf, polydog, metapetzai, paulaha11180...
# 16  2022-05-01 23:49:44  [sadiesupafli, ronereynold, dogepalooza, dogec...
# 17  2022-05-01 23:48:27  [38, 335, 200, worth, doge, sent, largest, sin...
# 18  2022-05-01 23:45:24  [sadiesupafli, ronereynold, dogepalooza, dogec...
# 19  2022-05-01 23:41:05  [selenaroyf, polydog, metapetzai, escobarbb371...
# 20  2022-05-01 23:41:02  [take, us, dogecoin, doge, dogearmi, http, co,...
# 21  2022-05-01 23:40:44  [current, price, one, doge, 0, 1332, 1, chang,...
# 22  2022-05-01 23:40:40  [unofficialterri, okaydog, elonmusk, dogecoin,...
# 23  2022-05-01 23:39:57  [raqueti21, okaydog, elonmusk, dogecoin, magic...
# 24  2022-05-01 23:39:13  [okaydog, giseller88, elonmusk, dogecoin, magi...
# 25  2022-05-01 23:38:12                 [gate, io, ye, good, result, doge]
# 26  2022-05-01 23:37:52  [victorydrop, okaydog, elonmusk, dogecoin, mag...
# 27  2022-05-01 23:34:22                       [doge, http, co, gxlfwtydcc]
# 28  2022-05-01 23:34:04  [man, doge, coin, everi, random, crypto, shill...
# 29  2022-05-01 23:32:12  [itsallriski, dog, bottom, middl, right, circl...
# 30  2022-05-01 23:31:22  [doge, danc, alan, jackson, good, time, offici...
# 31  2022-05-01 23:29:33  [farzadahangi, elonmusk, dogecoin, tdogewhispe...
# 32  2022-05-01 23:28:31  [vitainucoinpt, bitmartexchang, binancept, vin...
# 33  2022-05-01 23:28:26                       [doge, http, co, viwdzoqchg]
# 34  2022-05-01 23:27:27  [sadiesupafli, ronereynold, dogepalooza, dogec...
# 35  2022-05-01 23:27:00  [dogememegirl, dogecoin, know, also, help, gul...
# 36  2022-05-01 23:25:07              [gw, dejavu, doge, naik, ke, idr, 8k]
# 37  2022-05-01 23:23:12  [next, kiba, mri, doge, arriv, kinder, return,...
# 38  2022-05-01 23:22:08  [1b, bull, crypto, past, 7, day, symbol, 7d, y...
# 39  2022-05-01 23:22:03  [btc, 38411, 257, 1, 53, eth, 2816, 783, 2, 72...
#
#     negative  neutral  positive    comp
# 0      0.078    0.578     0.344  0.8481
# 1      0.000    1.000     0.000  0.0000
# 2      0.000    1.000     0.000  0.0000
# 3      0.000    1.000     0.000  0.0000
# 4      0.000    1.000     0.000  0.0000
# 5      0.125    0.875     0.000 -0.5106
# 6      0.143    0.857     0.000 -0.5423
# 7      0.000    1.000     0.000  0.0000
# 8      0.000    1.000     0.000  0.0000
# 9      0.000    1.000     0.000  0.0000
# 10     0.000    1.000     0.000  0.0000
# 11     0.146    0.786     0.068 -0.4404
# 12     0.000    1.000     0.000  0.0000
# 13     0.000    0.886     0.114  0.4019
# 14     0.000    0.750     0.250  0.2500
# 15     0.000    1.000     0.000  0.0000
# 16     0.000    1.000     0.000  0.0000
# 17     0.000    0.913     0.087  0.2263
# 18     0.000    1.000     0.000  0.0000
# 19     0.000    1.000     0.000  0.0000
# 20     0.000    1.000     0.000  0.0000
# 21     0.000    0.939     0.061  0.2263
# 22     0.000    0.800     0.200  0.3612
# 23     0.198    0.802     0.000 -0.5719
# 24     0.272    0.551     0.176 -0.5574
# 25     0.000    0.633     0.367  0.4404
# 26     0.000    1.000     0.000  0.0000
# 27     0.000    1.000     0.000  0.0000
# 28     0.000    1.000     0.000  0.0000
# 29     0.000    1.000     0.000  0.0000
# 30     0.000    0.818     0.182  0.4404
# 31     0.000    1.000     0.000  0.0000
# 32     0.000    1.000     0.000  0.0000
# 33     0.000    1.000     0.000  0.0000
# 34     0.000    1.000     0.000  0.0000
# 35     0.000    0.690     0.310  0.4019
# 36     0.000    1.000     0.000  0.0000
# 37     0.000    0.790     0.210  0.7269
# 38     0.000    1.000     0.000  0.0000
# 39     0.000    1.000     0.000  0.0000

# %%
final_doge.to_csv('doge.csv')
