# %%
import os
from google.cloud import language_v1
import pandas as pd
from cleantext import clean
import json
import glob
from pprint import pprint
import datetime
import re  
import nltk  
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ashlyn/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
ethereum_path = "Resources/ethereum.csv"

ethereum = pd.read_csv(ethereum_path)

ethereum.head(50)
# Out:
#                                            user_name  \
# 0                         #1 Crypto Currency TRADING
# 1                                             Reyrey
# 2                                        akter jahan
# 3                                              riyan
# 4                                   Michelle Eriksen
# 5                                        akter jahan
# 6                                        รังสิมันตุ์
# 7   Lucas, Rarible.com: BricksNft - buy,yet cheap..😀
# 8                      Stock Crypto News (Real-Time)
# 9                                         SURYAKAMAL
# 10                                 FXStockBroker.com
# 11                                   David Wilkinson
# 12                        REAL-TIME STOCK NEWS ALERT
# 13                                  Crypto.Pil◎t.S◎L
# 14                                 FromTheViewfinder
# 15                                     عَمرو عَیَّار
# 16                                          mohammad
# 17                                            76Arts
# 18                                           The Dux
# 19                                   Ethereum Hourly
# 20                                      profitsheets
# 21                                   David Wilkinson
# 22                                           Buu Inu
# 23                                           Shetrix
# 24                                      Crypto Buzzz
# 25            Ethereum Gas Custom Price Notifier Bot
# 26                                      RICO XAVIER🔺
# 27                                        Jack moris
# 28                                    Christo Crypto
# 29                                    Sara Laubscher
# 30                                   Al-Mokhtar NFTs
# 31                                              Aiko
# 32                                Charles A. Chanaba
# 33                                       Ricky Bobby
# 34                                   Cool Stuff Blog
# 35                                   Anup T Augustin
# 36                                Charles A. Chanaba
# 37  Lucas, Rarible.com: BricksNft - buy,yet cheap..😀
# 38                                          Tuhin420
# 39                                       mcswagg.eth
# 40                     Stock Crypto News (Real-Time)
# 41                                       Progrartist
# 42                                      Alyssa Rivas
# 43                               Gas Price Predictor
# 44                        REAL-TIME STOCK NEWS ALERT
# 45                              TH Ξ _F Ξ D ΞRIC_VII
# 46                                  🔥 MEMES + NFTs 🔥
# 47                                  Crypto Meditator
# 48                                     CryptoLucifer
# 49                                   Defimus Maximus
#
#                    user_location  \
# 0                            NaN
# 1                   Kuala Lumpur
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                London, England
# 8                            NaN
# 9                         Jaipur
# 10                           NaN
# 11                           NaN
# 12              Johnson City, VA
# 13                United States
# 14                         Kenya
# 15                  Fantasy Land
# 16                           NaN
# 17                           NaN
# 18                     Universe
# 19                           NaN
# 20                     Hyderabad
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                 Mumbai, India
# 25                           NaN
# 26            Prestige Worldwide
# 27                           NaN
# 28           Melbourne, Victoria
# 29                           NaN
# 30   Dubai, United Arab Emirates
# 31                           NaN
# 32  iPhone: 29.656776,-95.306160
# 33                 United States
# 34                     Ohio, USA
# 35                         India
# 36  iPhone: 29.656776,-95.306160
# 37               London, England
# 38           Comilla, Bangladesh
# 39                    5th floor
# 40                           NaN
# 41                       belgium
# 42                           NaN
# 43                           NaN
# 44              Johnson City, VA
# 45                     Metaverse
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49             Amazon Rainforest
#
#                                      user_description  \
# 0   Profit thought trading, Learn , Trade & Earn💲....
# 1   Artist | NFT Broker & Collector for AnideaNFT ...
# 2                                                 NaN
# 3                   i always paricipated your project
# 4                            Art Creator, NFT, Crypto
# 5                                                 NaN
# 6                                                 NaN
# 7   Brick's nft artist ,limited collections for va...
# 8   Get Real-Time Info about Live News, Signals an...
# 9   ⚽Goal \n\n🎧Music \n\n🏁Bike Rider   \n\n📞 +9189...
# 10  https://t.co/JQGltzeJwr has advanced trading p...
# 11                                                NaN
# 12  Stay on top of every headline that matters to ...
# 13                      #Bitcoin \n#Ethereum\n#Solana
# 14       Nature | Travel | Photography | Photosafari.
# 15  Amro is a fictional character of old Arabic st...
# 16  I am a designer and graphist and I want to pre...
# 17                              NFT Pixel Art Creator
# 18        Krypto is FUTURE! ETH & SOL till the Mars !
# 19  🤖 Follow me to get hourly Ethereum price updat...
# 20  profitsheets provide accurate information on I...
# 21                                                NaN
# 22  The most lovable villain of the Dragon Ball In...
# 23                                           #Bitcoin
# 24                                                NaN
# 25  1) Follow\n2) Turn on notifications\n3) Bot wi...
# 26  LOVE EVERYONE🔺🎱🚀MANIFEST POSITIVE ENERGY! ❤️ME...
# 27  Things our traders know: be careful of the hyp...
# 28  Came for the crypto, stayed for the memes. Meg...
# 29             Game Artist, Illustrator, Cool Grandpa
# 30  Private NFT collection All NFTs purchased it a...
# 31                                                NaN
# 32  #ChanabaMedia🔴🎥🎙🌎 #IASTM #Certified #Practitio...
# 33   These #LevelUp $Peeps $MXS\n $Shib Crypto world!
# 34  #investing #wordpress #lebronjames\n\nhttps://...
# 35  I'm an extensive reader. \nAnd I tend to share...
# 36  #ChanabaMedia🔴🎥🎙🌎 #IASTM #Certified #Practitio...
# 37  Brick's nft artist ,limited collections for va...
# 38  Crypto Lover\n\nFollow Back 100℅\nFollow Back ...
# 39  Kiss the girls goodbye don't peck em \nxbox:mc...
# 40  Get Real-Time Info about Live News, Signals an...
# 41  Crypto investor, Nft designer\n5% discount FTX...
# 42                                     A. Rivas Media
# 43  Gas used for transactions currently pending in...
# 44  Stay on top of every headline that matters to ...
# 45  Creative Director | 3d Visual Artist\n▲●◾ http...
# 46  Freshly Minted, Investment Gems #Ethereum #Pol...
# 47  Trading Cryptos\nCreating NFTs\nLoving all\nht...
# 48                                                NaN
# 49                       Serial Charity Token Addict!
#
#                  user_created  user_followers  user_friends  user_favourites  \
# 0   2021-11-10 10:42:01+00:00               4             0                0
# 1   2011-03-07 07:22:57+00:00             343           650              589
# 2   2021-10-28 13:28:05+00:00               1             2                0
# 3   2021-09-16 16:59:11+00:00              11           127               99
# 4   2021-08-11 06:40:08+00:00             522          1428               16
# 5   2021-10-28 13:28:05+00:00               1             2                0
# 6   2021-11-15 07:18:23+00:00               0             1                0
# 7   2021-07-14 10:45:01+00:00              76          1011              306
# 8   2021-08-19 10:51:41+00:00             158            15                2
# 9   2012-03-20 09:35:32+00:00             696           363              869
# 10  2017-02-14 02:53:42+00:00             141           174               12
# 11  2021-11-02 06:10:09+00:00               0             9                0
# 12  2020-08-24 16:32:36+00:00             341            39              507
# 13  2019-12-25 13:42:25+00:00             285          1408            23606
# 14  2020-08-09 15:15:40+00:00              62           101              762
# 15  2021-03-24 18:14:48+00:00             302           299             7205
# 16  2021-04-26 19:15:31+00:00             292          1193              296
# 17  2021-09-07 03:15:12+00:00              80           172              170
# 18  2021-11-10 08:32:00+00:00               1            28               19
# 19  2021-01-12 15:29:15+00:00             163             0                0
# 20  2019-12-31 04:10:19+00:00             112            78                0
# 21  2021-11-02 06:10:09+00:00               0             9                0
# 22  2021-11-03 07:42:34+00:00              53             1                1
# 23  2021-03-27 16:36:50+00:00              36            77             6130
# 24  2021-09-24 12:36:25+00:00              13           109              255
# 25  2021-01-04 09:25:56+00:00             710             0                0
# 26  2020-05-01 09:00:08+00:00              16            77              317
# 27  2021-03-07 18:28:55+00:00            3547             1               14
# 28  2021-08-04 12:42:37+00:00             127           351            22213
# 29  2020-06-03 19:57:35+00:00              32            68               32
# 30  2019-03-12 15:18:13+00:00              15             8               14
# 31  2021-10-26 10:35:46+00:00               0             0                0
# 32  2009-03-06 02:40:11+00:00            1365          2042              855
# 33  2013-04-30 16:30:12+00:00             317           181             3251
# 34  2011-11-09 00:54:29+00:00            1517          4971             1160
# 35  2013-03-27 15:58:56+00:00              38            66             1252
# 36  2009-03-06 02:40:11+00:00            1365          2042              855
# 37  2021-07-14 10:45:01+00:00              76          1011              306
# 38  2019-01-05 11:41:42+00:00            1163          2154              348
# 39  2010-09-25 17:40:48+00:00             183           176              621
# 40  2021-08-19 10:51:41+00:00             158            15                2
# 41  2009-12-08 10:41:18+00:00             826          1613                8
# 42  2015-09-08 23:53:18+00:00             129           107              647
# 43  2020-08-16 06:31:14+00:00            2857          2456             4384
# 44  2020-08-24 16:32:36+00:00             341            39              507
# 45  2020-08-23 17:42:19+00:00             258          1050             2705
# 46  2021-10-30 05:30:58+00:00               5            11               11
# 47  2021-02-20 13:04:57+00:00             750           263             3161
# 48  2021-10-07 07:10:59+00:00              21            25              219
# 49  2020-08-28 09:53:42+00:00             103            76              692
#
#     user_verified                       date  \
# 0           False  2021-11-15 07:26:39+00:00
# 1           False  2021-11-15 07:26:35+00:00
# 2           False  2021-11-15 07:26:32+00:00
# 3           False  2021-11-15 07:26:30+00:00
# 4           False  2021-11-15 07:26:30+00:00
# 5           False  2021-11-15 07:25:51+00:00
# 6           False  2021-11-15 07:25:39+00:00
# 7           False  2021-11-15 07:25:36+00:00
# 8           False  2021-11-15 07:25:25+00:00
# 9           False  2021-11-15 07:25:14+00:00
# 10          False  2021-11-15 07:25:08+00:00
# 11          False  2021-11-15 07:25:04+00:00
# 12          False  2021-11-15 07:24:57+00:00
# 13          False  2021-11-15 07:24:48+00:00
# 14          False  2021-11-15 07:24:38+00:00
# 15          False  2021-11-15 07:24:36+00:00
# 16          False  2021-11-15 07:24:29+00:00
# 17          False  2021-11-15 07:24:11+00:00
# 18          False  2021-11-15 07:23:48+00:00
# 19          False  2021-11-15 07:23:41+00:00
# 20          False  2021-11-15 07:23:38+00:00
# 21          False  2021-11-15 07:23:29+00:00
# 22          False  2021-11-15 07:23:19+00:00
# 23          False  2021-11-15 07:23:09+00:00
# 24          False  2021-11-15 07:22:56+00:00
# 25          False  2021-11-15 07:22:53+00:00
# 26          False  2021-11-15 07:22:50+00:00
# 27          False  2021-11-15 07:22:48+00:00
# 28          False  2021-11-15 07:22:36+00:00
# 29          False  2021-11-15 07:22:13+00:00
# 30          False  2021-11-15 07:22:02+00:00
# 31          False  2021-11-15 07:21:45+00:00
# 32          False  2021-11-15 07:20:40+00:00
# 33          False  2021-11-15 07:20:09+00:00
# 34          False  2021-11-15 07:19:56+00:00
# 35          False  2021-11-15 07:19:39+00:00
# 36          False  2021-11-15 07:19:35+00:00
# 37          False  2021-11-15 07:19:30+00:00
# 38          False  2021-11-15 07:19:26+00:00
# 39          False  2021-11-15 07:19:22+00:00
# 40          False  2021-11-15 07:19:15+00:00
# 41          False  2021-11-15 07:19:08+00:00
# 42          False  2021-11-15 07:19:01+00:00
# 43          False  2021-11-15 07:18:57+00:00
# 44          False  2021-11-15 07:18:52+00:00
# 45          False  2021-11-15 07:18:45+00:00
# 46          False  2021-11-15 07:18:45+00:00
# 47          False  2021-11-15 07:18:41+00:00
# 48          False  2021-11-15 07:18:40+00:00
# 49          False  2021-11-15 07:18:03+00:00
#
#                                                  text  \
# 0   Get upto 1000 that’s 10x with our premium spot...
# 1   Adopted a Hypocat #053, “Crazy Rich Cat” 🤑💵💵💵🤩...
# 2   Top 10 Coins by Social Engagement over the las...
# 3   Requesting faucet funds into 0x5278942b39deD8c...
# 4   New Listing BTS 0.008ETH !! \n#NFTs  #nftcolle...
# 5   Top 10 Coins by Social Volume over the last 24...
# 6   This is my First art you can purchase my The c...
# 7   I've just minted "Waterfall graph " collectibl...
# 8   Crypto Prices (USD/₿)\n\nBitcoin ➨ $65710.3048...
# 9   You can do Cloud Mining using this site https:...
# 10  ANIMOCA BRANDS UNVEILS PLANS FOR K-POP NFT MET...
# 11  Requesting faucet funds into 0x174d78F4dacDc28...
# 12  Crypto Prices (USD/₿)\n\nBitcoin ➦ $65707.803➷...
# 13  @michaeljburry @elonmusk @BernieSanders Just #...
# 14  Trying out something new. NFT account up and r...
# 15  Top 10 coins by 3-months Twitter Volume \n\n$b...
# 16  I've just minted "Predatory wolf #124" collect...
# 17  Requesting faucet funds into 0x67ccb9fb7d07dbc...
# 18  @elonmusk Everyone will invest soon ! #Bitcoin...
# 19               Current #Ethereum Price: $4,697.90 📉
# 20  Hero MotoCorp share after Q2 results: Should y...
# 21  Hero MotoCorp share after Q2 results: Should y...
# 22  🔥 Another teaser from one of our Generative NF...
# 23  Having no $WIN &amp; $LTC in my portfolio woul...
# 24  Today Crypto currency Top 10 Gainers and loser...
# 25  Slow 101 | Normal 108 | Fast 123 | Instant 142...
# 26  #bitcoin #SHIB #Ethereum @TomCruise I KNOW YOU...
# 27  Top 10 #cryptocurrencies in the world by Twitt...
# 28  Ok i have 45k USD to ape into some project, pl...
# 29  I've just minted "The Aloes" collectible! http...
# 30  My Neighbor Alice NFT\nFright Night at Alice’s...
# 31  Requesting faucet funds into 0x70783B552b9EcFe...
# 32  EtherBear #etherbears #ethereum #tothemoon #bu...
# 33  Everyone loved what @MXStoken did today? \n🚨 B...
# 34  0.001 Litecoin(LTC) Crypto Mining-Contract (0....
# 35  Unpopular opinion:\n\nReal money is being made...
# 36  EtherBear #etherbears #ethereum #tothemoon #bu...
# 37  PLS RETWEET I've just minted NFT "FILTERED Bra...
# 38  This strong team and reliable idea make this g...
# 39  I hope this is a sign of what's to come. Tryin...
# 40  Crypto Prices (USD/₿)\n\nBitcoin ➨ $65729.1713...
# 41  #Ethereum December future on #Binance is tradi...
# 42  I've just minted "Collectible poster for Oh It...
# 43  Gas used in currently pending transactions:\n\...
# 44  Crypto Prices (USD/₿)\n\nBitcoin ➦ $65717.475➶...
# 45  Buying art from great artists is easy, betting...
# 46  Check out my NFT listing on OpenSea! https://t...
# 47  #Bitcoin Is approaching 0.618 Fib Level, seems...
# 48  HADES wins the poll 🔥\nLETSGOOOO💪🤩\n\n#UnoRe #...
# 49  🧡💛💚💙 Pawthereum (PAWTH) is making moves.. &gt;...
#
#                                              hashtags               source  \
# 0                                                 NaN  Twitter for Android
# 1   ['SupportingCreators', 'CryptoArt', 'CryptoArt...   Twitter for iPhone
# 2               ['LunarCrush', 'bitcoin', 'dogecoin']      Twitter Web App
# 3                             ['Rinkeby', 'Ethereum']      Twitter Web App
# 4   ['NFTs', 'nftcollector', 'NFTCommunity', 'art'...      Twitter Web App
# 5   ['LunarCrush', 'bitcoin', 'shibainu', 'ethereum']      Twitter Web App
# 6                                                 NaN   Twitter for iPhone
# 7      ['rarible', 'ethereum', 'flow', 'nonfungible']  Twitter for Android
# 8                                                 NaN             Aida_bot
# 9   ['mining', 'dogemining', 'trxmining', 'btcmini...  Twitter for Android
# 10                        ['Crypto', 'cryptotrading']      Twitter Web App
# 11                            ['Rinkeby', 'Ethereum']      Twitter Web App
# 12                                                NaN        FactCheckBot5
# 13                            ['Bitcoin', 'Ethereum']  Twitter for Android
# 14                                                NaN      Twitter Web App
# 15  ['bitcoin', 'ethereum', 'shibainu', 'pancakesw...      Twitter Web App
# 16     ['rarible', 'ethereum', 'flow', 'nonfungible']      Twitter Web App
# 17                            ['Rinkeby', 'Ethereum']      Twitter Web App
# 18                  ['Bitcoin', 'Ethereum', 'Solana']      Twitter Web App
# 19                                       ['Ethereum']      EtheriumTwitter
# 20                                     ['HEROMOTOCO']      Twitter Web App
# 21                            ['Rinkeby', 'Ethereum']      Twitter Web App
# 22                                                NaN      Twitter Web App
# 23                                                NaN  Twitter for Android
# 24            ['crypto', 'bitcoin', 'cryptocurrency']  Twitter for Android
# 25                                                NaN       EthGasPriceBot
# 26                    ['bitcoin', 'SHIB', 'Ethereum']   Twitter for iPhone
# 27  ['cryptocurrencies', 'BNB', 'Bitcoin', 'Dogeco...  Twitter for Android
# 28               ['BTC', 'Ethereum', 'cryptocurrecy']      Twitter Web App
# 29  ['rarible', 'ethereum', 'flow', 'nonfungible',...  Twitter for Android
# 30                                    ['nfts', 'nft']   Twitter for iPhone
# 31                            ['Rinkeby', 'Ethereum']      Twitter Web App
# 32  ['etherbears', 'ethereum', 'tothemoon', 'bulli...              Echofon
# 33                                       ['Ethereum']  Twitter for Android
# 34  ['crypto', 'cryptocurrency', 'bitcoin', 'dogec...        FS-Poster APP
# 35                ['Altcoins', 'Bitcoin', 'Ethereum']  Twitter for Android
# 36  ['etherbears', 'ethereum', 'tothemoon', 'bulli...              Echofon
# 37                          ['nfts', 'NFTcollection']  Twitter for Android
# 38                                                NaN      Twitter Web App
# 39  ['Crypto', 'Ethereum', 'ETH', 'BTC', 'NFTs', '...  Twitter for Android
# 40                                                NaN             Aida_bot
# 41                            ['Ethereum', 'Binance']        market_alerts
# 42                            ['rarible', 'ethereum']      Twitter Web App
# 43                                                NaN           Integromat
# 44                                                NaN        FactCheckBot5
# 45                                                NaN   Twitter for iPhone
# 46                                                NaN   Twitter for iPhone
# 47                                        ['Bitcoin']      Twitter Web App
# 48  ['UnoRe', 'Reinsurance', 'Crypto', 'Cryptocurr...      Twitter Web App
# 49                                                NaN           pawthwreum
#
#     is_retweet
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False

# %%
df = ethereum.filter(['text','date'])[0:10000]

df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                                                    text  \
# 0     Get upto 1000 thats 10x with our premium spot ...
# 1     Adopted a Hypocat #053, Crazy Rich Cat  @hypoc...
# 2     Top 10 Coins by Social Engagement over the las...
# 3     Requesting faucet funds into 0x5278942b39deD8c...
# 4     New Listing BTS 0.008ETH !! \n#NFTs  #nftcolle...
# ...                                                 ...
# 9995  Pepe the gunman II\n\nhttps://t.co/xTOJSvLwX9 ...
# 9996  @missteennfts  TOODLER 1:1 EDITION \nPlease vi...
# 9997  Hello guys! mind to view my project at opensea...
# 9998  Ethereum: One major misconception that will no...
# 9999  Giovanni Simeone bought for 0.238 ETH (1100.25...
#
#                            date
# 0     2021-11-15 07:26:39+00:00
# 1     2021-11-15 07:26:35+00:00
# 2     2021-11-15 07:26:32+00:00
# 3     2021-11-15 07:26:30+00:00
# 4     2021-11-15 07:26:30+00:00
# ...                         ...
# 9995  2021-11-14 13:43:00+00:00
# 9996  2021-11-14 13:42:56+00:00
# 9997  2021-11-14 13:42:42+00:00
# 9998  2021-11-14 13:42:31+00:00
# 9999  2021-11-14 13:42:25+00:00
#
# [10000 rows x 2 columns]

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

# %%
cleantext=[]
for item in tqdm(df['text']):
    words=tweet_to_words(item)
    cleantext+=[words]
df['cleaned']=cleantext
df
# Out:
# 100%|████████████████████████████████████| 10000/10000 [00:33<00:00, 298.35it/s]
#                                                    text  \
# 0     Get upto 1000 that’s 10x with our premium spot...
# 1     Adopted a Hypocat #053, “Crazy Rich Cat” 🤑💵💵💵🤩...
# 2     Top 10 Coins by Social Engagement over the las...
# 3     Requesting faucet funds into 0x5278942b39deD8c...
# 4     New Listing BTS 0.008ETH !! \n#NFTs  #nftcolle...
# ...                                                 ...
# 9995  Pepe the gunman II\n\nhttps://t.co/xTOJSvLwX9 ...
# 9996  @missteennfts 🔥 TOODLER 1:1 EDITION 🔥\nPlease ...
# 9997  Hello guys! mind to view my project at opensea...
# 9998  Ethereum: One major misconception that will no...
# 9999  Giovanni Simeone bought for 0.238 ETH (1100.25...
#
#                            date  \
# 0     2021-11-15 07:26:39+00:00
# 1     2021-11-15 07:26:35+00:00
# 2     2021-11-15 07:26:32+00:00
# 3     2021-11-15 07:26:30+00:00
# 4     2021-11-15 07:26:30+00:00
# ...                         ...
# 9995  2021-11-14 13:43:00+00:00
# 9996  2021-11-14 13:42:56+00:00
# 9997  2021-11-14 13:42:42+00:00
# 9998  2021-11-14 13:42:31+00:00
# 9999  2021-11-14 13:42:25+00:00
#
#                                                 cleaned
# 0     [get, upto, 1000, 10x, premium, spot, trade, s...
# 1     [adopt, hypocat, 053, crazi, rich, cat, hypoca...
# 2     [top, 10, coin, social, engag, last, 24, hr, l...
# 3     [request, faucet, fund, 0x5278942b39ded8cbdad9...
# 4     [new, list, bt, 0, 008eth, nft, nftcollector, ...
# ...                                                 ...
# 9995  [pepe, gunman, ii, http, co, xtojsvlwx9, nftar...
# 9996  [missteennft, toodler, 1, 1, edit, pleas, visi...
# 9997  [hello, guy, mind, view, project, opensea, alr...
# 9998  [ethereum, one, major, misconcept, dictat, sho...
# 9999  [giovanni, simeon, bought, 0, 238, eth, 1100, ...
#
# [10000 rows x 3 columns]

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
def compute_vader_scores(df, label):
    sid = SentimentIntensityAnalyzer()
    df["negative"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neg"])
    df["neutral"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neu"])
    df["positive"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["pos"])
    df["comp"] = df[label].apply(lambda x: sid.polarity_scores(unlist(x))["compound"])
    return df

# %%
final_ethereum = compute_vader_scores(df,'cleaned')
final_ethereum
# Out:
#                                                    text  \
# 0     Get upto 1000 that’s 10x with our premium spot...
# 1     Adopted a Hypocat #053, “Crazy Rich Cat” 🤑💵💵💵🤩...
# 2     Top 10 Coins by Social Engagement over the las...
# 3     Requesting faucet funds into 0x5278942b39deD8c...
# 4     New Listing BTS 0.008ETH !! \n#NFTs  #nftcolle...
# ...                                                 ...
# 9995  Pepe the gunman II\n\nhttps://t.co/xTOJSvLwX9 ...
# 9996  @missteennfts 🔥 TOODLER 1:1 EDITION 🔥\nPlease ...
# 9997  Hello guys! mind to view my project at opensea...
# 9998  Ethereum: One major misconception that will no...
# 9999  Giovanni Simeone bought for 0.238 ETH (1100.25...
#
#                            date  \
# 0     2021-11-15 07:26:39+00:00
# 1     2021-11-15 07:26:35+00:00
# 2     2021-11-15 07:26:32+00:00
# 3     2021-11-15 07:26:30+00:00
# 4     2021-11-15 07:26:30+00:00
# ...                         ...
# 9995  2021-11-14 13:43:00+00:00
# 9996  2021-11-14 13:42:56+00:00
# 9997  2021-11-14 13:42:42+00:00
# 9998  2021-11-14 13:42:31+00:00
# 9999  2021-11-14 13:42:25+00:00
#
#                                                 cleaned  negative  neutral  \
# 0     [get, upto, 1000, 10x, premium, spot, trade, s...       0.0    1.000
# 1     [adopt, hypocat, 053, crazi, rich, cat, hypoca...       0.0    0.813
# 2     [top, 10, coin, social, engag, last, 24, hr, l...       0.0    0.938
# 3     [request, faucet, fund, 0x5278942b39ded8cbdad9...       0.0    1.000
# 4     [new, list, bt, 0, 008eth, nft, nftcollector, ...       0.0    1.000
# ...                                                 ...       ...      ...
# 9995  [pepe, gunman, ii, http, co, xtojsvlwx9, nftar...       0.0    1.000
# 9996  [missteennft, toodler, 1, 1, edit, pleas, visi...       0.0    1.000
# 9997  [hello, guy, mind, view, project, opensea, alr...       0.0    0.843
# 9998  [ethereum, one, major, misconcept, dictat, sho...       0.0    1.000
# 9999  [giovanni, simeon, bought, 0, 238, eth, 1100, ...       0.0    1.000
#
#       positive    comp
# 0        0.000  0.0000
# 1        0.187  0.6486
# 2        0.062  0.2023
# 3        0.000  0.0000
# 4        0.000  0.0000
# ...        ...     ...
# 9995     0.000  0.0000
# 9996     0.000  0.0000
# 9997     0.157  0.6597
# 9998     0.000  0.0000
# 9999     0.000  0.0000
#
# [10000 rows x 7 columns]

# %%
# print(len(date), len(final_bitcoin.cleaned),len(final_bitcoin.negative),len(final_bitcoin.comp),len(final_bitcoin.neutral))

# %%
# final_bitcoin.isnull().values.any()

final_ethereum[['dates','Time']] = final_ethereum.date.str.split("+",expand=True)

final_ethereum
# Out:
#                                                    text  \
# 0     Get upto 1000 that’s 10x with our premium spot...
# 1     Adopted a Hypocat #053, “Crazy Rich Cat” 🤑💵💵💵🤩...
# 2     Top 10 Coins by Social Engagement over the las...
# 3     Requesting faucet funds into 0x5278942b39deD8c...
# 4     New Listing BTS 0.008ETH !! \n#NFTs  #nftcolle...
# ...                                                 ...
# 9995  Pepe the gunman II\n\nhttps://t.co/xTOJSvLwX9 ...
# 9996  @missteennfts 🔥 TOODLER 1:1 EDITION 🔥\nPlease ...
# 9997  Hello guys! mind to view my project at opensea...
# 9998  Ethereum: One major misconception that will no...
# 9999  Giovanni Simeone bought for 0.238 ETH (1100.25...
#
#                            date  \
# 0     2021-11-15 07:26:39+00:00
# 1     2021-11-15 07:26:35+00:00
# 2     2021-11-15 07:26:32+00:00
# 3     2021-11-15 07:26:30+00:00
# 4     2021-11-15 07:26:30+00:00
# ...                         ...
# 9995  2021-11-14 13:43:00+00:00
# 9996  2021-11-14 13:42:56+00:00
# 9997  2021-11-14 13:42:42+00:00
# 9998  2021-11-14 13:42:31+00:00
# 9999  2021-11-14 13:42:25+00:00
#
#                                                 cleaned  negative  neutral  \
# 0     [get, upto, 1000, 10x, premium, spot, trade, s...       0.0    1.000
# 1     [adopt, hypocat, 053, crazi, rich, cat, hypoca...       0.0    0.813
# 2     [top, 10, coin, social, engag, last, 24, hr, l...       0.0    0.938
# 3     [request, faucet, fund, 0x5278942b39ded8cbdad9...       0.0    1.000
# 4     [new, list, bt, 0, 008eth, nft, nftcollector, ...       0.0    1.000
# ...                                                 ...       ...      ...
# 9995  [pepe, gunman, ii, http, co, xtojsvlwx9, nftar...       0.0    1.000
# 9996  [missteennft, toodler, 1, 1, edit, pleas, visi...       0.0    1.000
# 9997  [hello, guy, mind, view, project, opensea, alr...       0.0    0.843
# 9998  [ethereum, one, major, misconcept, dictat, sho...       0.0    1.000
# 9999  [giovanni, simeon, bought, 0, 238, eth, 1100, ...       0.0    1.000
#
#       positive    comp                dates   Time
# 0        0.000  0.0000  2021-11-15 07:26:39  00:00
# 1        0.187  0.6486  2021-11-15 07:26:35  00:00
# 2        0.062  0.2023  2021-11-15 07:26:32  00:00
# 3        0.000  0.0000  2021-11-15 07:26:30  00:00
# 4        0.000  0.0000  2021-11-15 07:26:30  00:00
# ...        ...     ...                  ...    ...
# 9995     0.000  0.0000  2021-11-14 13:43:00  00:00
# 9996     0.000  0.0000  2021-11-14 13:42:56  00:00
# 9997     0.157  0.6597  2021-11-14 13:42:42  00:00
# 9998     0.000  0.0000  2021-11-14 13:42:31  00:00
# 9999     0.000  0.0000  2021-11-14 13:42:25  00:00
#
# [10000 rows x 9 columns]

# %%
final_ethereum = final_ethereum.filter(['dates', 'cleaned','negative','neutral','positive','comp'])
final_ethereum.head(40)
# Out:
#                   dates                                            cleaned  \
# 0   2021-11-15 07:26:39  [get, upto, 1000, 10x, premium, spot, trade, s...
# 1   2021-11-15 07:26:35  [adopt, hypocat, 053, crazi, rich, cat, hypoca...
# 2   2021-11-15 07:26:32  [top, 10, coin, social, engag, last, 24, hr, l...
# 3   2021-11-15 07:26:30  [request, faucet, fund, 0x5278942b39ded8cbdad9...
# 4   2021-11-15 07:26:30  [new, list, bt, 0, 008eth, nft, nftcollector, ...
# 5   2021-11-15 07:25:51  [top, 10, coin, social, volum, last, 24, hr, l...
# 6   2021-11-15 07:25:39  [first, art, purchas, cutest, penguin, nft, ra...
# 7   2021-11-15 07:25:36  [mint, waterfal, graph, collect, http, co, wr0...
# 8   2021-11-15 07:25:25  [crypto, price, usd, bitcoin, 65710, 3048, eth...
# 9   2021-11-15 07:25:14  [cloud, mine, use, site, http, co, kgkt72uqa6,...
# 10  2021-11-15 07:25:08  [animoca, brand, unveil, plan, k, pop, nft, me...
# 11  2021-11-15 07:25:04  [request, faucet, fund, 0x174d78f4dacdc286fb54...
# 12  2021-11-15 07:24:57  [crypto, price, usd, bitcoin, 65707, 803, ethe...
# 13  2021-11-15 07:24:48  [michaeljburri, elonmusk, berniesand, bitcoin,...
# 14  2021-11-15 07:24:38  [tri, someth, new, nft, account, run, take, lo...
# 15  2021-11-15 07:24:36  [top, 10, coin, 3, month, twitter, volum, btc,...
# 16  2021-11-15 07:24:29  [mint, predatori, wolf, 124, collect, http, co...
# 17  2021-11-15 07:24:11  [request, faucet, fund, 0x67ccb9fb7d07dbc4118d...
# 18  2021-11-15 07:23:48  [elonmusk, everyon, invest, soon, bitcoin, eth...
# 19  2021-11-15 07:23:41             [current, ethereum, price, 4, 697, 90]
# 20  2021-11-15 07:23:38  [hero, motocorp, share, q2, result, buy, sell,...
# 21  2021-11-15 07:23:29  [hero, motocorp, share, q2, result, buy, sell,...
# 22  2021-11-15 07:23:19  [anoth, teaser, one, gener, nft, present, buu,...
# 23  2021-11-15 07:23:09  [win, amp, ltc, portfolio, would, get, sleeple...
# 24  2021-11-15 07:22:56  [today, crypto, currenc, top, 10, gainer, lose...
# 25  2021-11-15 07:22:53  [slow, 101, normal, 108, fast, 123, instant, 1...
# 26  2021-11-15 07:22:50  [bitcoin, shib, ethereum, tomcruis, know, part...
# 27  2021-11-15 07:22:48  [top, 10, cryptocurr, world, twitter, follow, ...
# 28  2021-11-15 07:22:36  [ok, 45k, usd, ape, project, pl, suggest, best...
# 29  2021-11-15 07:22:13  [mint, alo, collect, http, co, in9rfvbvdv, rar...
# 30  2021-11-15 07:22:02  [neighbor, alic, nft, fright, night, alic, far...
# 31  2021-11-15 07:21:45  [request, faucet, fund, 0x70783b552b9ecfee75b5...
# 32  2021-11-15 07:20:40  [etherbear, etherbear, ethereum, tothemoon, bu...
# 33  2021-11-15 07:20:09  [everyon, love, mxstoken, today, buy, 25billio...
# 34  2021-11-15 07:19:56  [0, 001, litecoin, ltc, crypto, mine, contract...
# 35  2021-11-15 07:19:39  [unpopular, opinion, real, money, made, invest...
# 36  2021-11-15 07:19:35  [etherbear, etherbear, ethereum, tothemoon, bu...
# 37  2021-11-15 07:19:30  [pl, retweet, mint, nft, filter, brain, collec...
# 38  2021-11-15 07:19:26  [strong, team, reliabl, idea, make, great, pro...
# 39  2021-11-15 07:19:22  [hope, sign, come, tri, quit, day, job, crypto...
#
#     negative  neutral  positive    comp
# 0      0.000    1.000     0.000  0.0000
# 1      0.000    0.813     0.187  0.6486
# 2      0.000    0.938     0.062  0.2023
# 3      0.000    1.000     0.000  0.0000
# 4      0.000    1.000     0.000  0.0000
# 5      0.000    0.938     0.062  0.2023
# 6      0.000    0.840     0.160  0.5859
# 7      0.000    1.000     0.000  0.0000
# 8      0.000    1.000     0.000  0.0000
# 9      0.000    1.000     0.000  0.0000
# 10     0.000    1.000     0.000  0.0000
# 11     0.000    1.000     0.000  0.0000
# 12     0.000    1.000     0.000  0.0000
# 13     0.000    1.000     0.000  0.0000
# 14     0.000    0.925     0.075  0.2960
# 15     0.000    0.942     0.058  0.2023
# 16     0.000    1.000     0.000  0.0000
# 17     0.000    1.000     0.000  0.0000
# 18     0.000    1.000     0.000  0.0000
# 19     0.000    1.000     0.000  0.0000
# 20     0.000    0.674     0.326  0.8910
# 21     0.000    0.674     0.326  0.8910
# 22     0.056    0.944     0.000 -0.2500
# 23     0.000    0.749     0.251  0.8658
# 24     0.097    0.852     0.051 -0.3818
# 25     0.084    0.916     0.000 -0.2732
# 26     0.000    0.711     0.289  0.7579
# 27     0.000    0.943     0.057  0.2023
# 28     0.000    0.670     0.330  0.7506
# 29     0.000    1.000     0.000  0.0000
# 30     0.075    0.925     0.000 -0.3818
# 31     0.000    1.000     0.000  0.0000
# 32     0.000    1.000     0.000  0.0000
# 33     0.000    0.764     0.236  0.8720
# 34     0.000    1.000     0.000  0.0000
# 35     0.000    1.000     0.000  0.0000
# 36     0.000    1.000     0.000  0.0000
# 37     0.000    1.000     0.000  0.0000
# 38     0.000    0.684     0.316  0.9022
# 39     0.000    0.854     0.146  0.4404

# %%
final_ethereum.to_csv('ethereum.csv')
