# %%
import os
from google.cloud import language_v1
import pandas as pd
from cleantext import clean
import json
import glob
from pprint import pprint
import datetime
import re 
import glob
import nltk  
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ashlyn/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
dollar_bitcoin_df = pd.read_csv("../Resources/dollar_bitcoin_1.csv",lineterminator='\n')
for i in range(1, 16):
    df = pd.read_csv(f"../Resources/dollar_bitcoin_{i}.csv",lineterminator='\n')
    dollar_bitcoin_df = pd.concat([dollar_bitcoin_df, df], axis=0)
    
dollar_bitcoin_df.head()
# Out:
#    Unnamed: 0                   Datetime  \
# 0           0  2022-05-01 23:59:56+00:00
# 1           1  2022-05-01 23:59:56+00:00
# 2           2  2022-05-01 23:59:53+00:00
# 3           3  2022-05-01 23:59:52+00:00
# 4           4  2022-05-01 23:59:50+00:00
#
#                                                 Text
# 0  Oh you think im just pulling this out my ass!?...
# 1  @Cryptic_Oz Bitcoin es baloncesto! https://t.c...
# 2  UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...
# 3  I’ve realized I’m not attracted to religions w...
# 4  This is ridiculous. Those are stocks! \n\nBitc...

# %%
dollar_bitcoin_df = dollar_bitcoin_df.filter(['Text','Datetime'])

dollar_bitcoin_df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                                                     Text  \
# 0      Oh you think im just pulling this out my ass!?...
# 1      @Cryptic_Oz Bitcoin es baloncesto! https://t.c...
# 2      UN LONG A SANDBOX !! #sandbox #crypto #bitcoin...
# 3      Ive realized Im not attracted to religions whe...
# 4      This is ridiculous. Those are stocks! \n\nBitc...
# ...                                                  ...
# 9996   Wall Streetin kurdu kripto kurslar iin kii ba ...
# 9997   Huge buying power $kda from 72 hours ago will ...
# 9998   #EducacionFinanciera\n#Bitcoin talks #crytocur...
# 9999   Analysis May 15th\n\nThe current price of $BTC...
# 10000  @TheJackForge Do we have to pay in $, Bitcoin ...
#
#                         Datetime
# 0      2022-05-01 23:59:56+00:00
# 1      2022-05-01 23:59:56+00:00
# 2      2022-05-01 23:59:53+00:00
# 3      2022-05-01 23:59:52+00:00
# 4      2022-05-01 23:59:50+00:00
# ...                          ...
# 9996   2022-05-15 19:54:28+00:00
# ...

# %%
dollar_bitcoin_df.to_csv('dollar_bitcoin.csv')

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    words = text.split()
    words = [w for w in words if w not in stopwords.words("english")]
    words = [PorterStemmer().stem(w) for w in words]
    return words

# %%
cleantext=[]
for item in tqdm(dollar_bitcoin_df['Text']):
    words=tweet_to_words(item)
    cleantext+=[words]
dollar_bitcoin_df['cleaned']=cleantext
dollar_bitcoin_df
# Out:
# 100%|██████████████████████████████████| 160016/160016 [21:09<00:00, 126.07it/s]
#                                                     Text  \
# 0      Oh you think im just pulling this out my ass!?...
# 1      @Cryptic_Oz Bitcoin es baloncesto! https://t.c...
# 2      UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...
# 3      I’ve realized I’m not attracted to religions w...
# 4      This is ridiculous. Those are stocks! \n\nBitc...
# ...                                                  ...
# 9996   “Wall Street’in kurdu” kripto kursları için ki...
# 9997   Huge buying power $kda from 72 hours ago will ...
# 9998   #EducacionFinanciera\n#Bitcoin talks #crytocur...
# 9999   📈Analysis May 15th📈\n\nThe current price of $B...
# 10000  @TheJackForge Do we have to pay in 🇨🇦$, Bitcoi...
#
#                         Datetime  \
# 0      2022-05-01 23:59:56+00:00
# 1      2022-05-01 23:59:56+00:00
# 2      2022-05-01 23:59:53+00:00
# 3      2022-05-01 23:59:52+00:00
# ...

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
def compute_vader_scores(dollar_bitcoin_df, label):
    sid = SentimentIntensityAnalyzer()
    dollar_bitcoin_df["negative"] = dollar_bitcoin_df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neg"])
    dollar_bitcoin_df["neutral"] = dollar_bitcoin_df[label].apply(lambda x: sid.polarity_scores(unlist(x))["neu"])
    dollar_bitcoin_df["positive"] = dollar_bitcoin_df[label].apply(lambda x: sid.polarity_scores(unlist(x))["pos"])
    dollar_bitcoin_df["comp"] = dollar_bitcoin_df[label].apply(lambda x: sid.polarity_scores(unlist(x))["compound"])
    return dollar_bitcoin_df

# %%
final_bitcoin = compute_vader_scores(dollar_bitcoin_df,'cleaned')
final_bitcoin
# Out:
#                                                     Text  \
# 0      Oh you think im just pulling this out my ass!?...
# 1      @Cryptic_Oz Bitcoin es baloncesto! https://t.c...
# 2      UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...
# 3      I’ve realized I’m not attracted to religions w...
# 4      This is ridiculous. Those are stocks! \n\nBitc...
# ...                                                  ...
# 9996   “Wall Street’in kurdu” kripto kursları için ki...
# 9997   Huge buying power $kda from 72 hours ago will ...
# 9998   #EducacionFinanciera\n#Bitcoin talks #crytocur...
# 9999   📈Analysis May 15th📈\n\nThe current price of $B...
# 10000  @TheJackForge Do we have to pay in 🇨🇦$, Bitcoi...
#
#                         Datetime  \
# 0      2022-05-01 23:59:56+00:00
# 1      2022-05-01 23:59:56+00:00
# 2      2022-05-01 23:59:53+00:00
# 3      2022-05-01 23:59:52+00:00
# 4      2022-05-01 23:59:50+00:00
# ...                          ...
# 9996   2022-05-15 19:54:28+00:00
# ...

# %%
# print(len(date), len(final_bitcoin.cleaned),len(final_bitcoin.negative),len(final_bitcoin.comp),len(final_bitcoin.neutral))

# %%
# final_bitcoin.isnull().values.any()

final_bitcoin[['dates','Time']] = final_bitcoin.Datetime.str.split("+",expand=True)

final_bitcoin
# Out:
#                                                     Text  \
# 0      Oh you think im just pulling this out my ass!?...
# 1      @Cryptic_Oz Bitcoin es baloncesto! https://t.c...
# 2      UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...
# 3      I’ve realized I’m not attracted to religions w...
# 4      This is ridiculous. Those are stocks! \n\nBitc...
# ...                                                  ...
# 9996   “Wall Street’in kurdu” kripto kursları için ki...
# 9997   Huge buying power $kda from 72 hours ago will ...
# 9998   #EducacionFinanciera\n#Bitcoin talks #crytocur...
# 9999   📈Analysis May 15th📈\n\nThe current price of $B...
# 10000  @TheJackForge Do we have to pay in 🇨🇦$, Bitcoi...
#
#                         Datetime  \
# 0      2022-05-01 23:59:56+00:00
# 1      2022-05-01 23:59:56+00:00
# 2      2022-05-01 23:59:53+00:00
# 3      2022-05-01 23:59:52+00:00
# 4      2022-05-01 23:59:50+00:00
# ...                          ...
# 9996   2022-05-15 19:54:28+00:00
# ...

# %%
final_bitcoin = final_bitcoin.filter(['dates', 'cleaned','negative','neutral','positive','comp'])
final_bitcoin.head(40)
# Out:
#                   dates                                            cleaned  \
# 0   2022-05-01 23:59:56  [oh, think, im, pull, ass, bitcoin, http, co, ...
# 1   2022-05-01 23:59:56  [cryptic, oz, bitcoin, es, baloncesto, http, c...
# 2   2022-05-01 23:59:53  [un, long, sandbox, sandbox, crypto, bitcoin, ...
# 3   2022-05-01 23:59:52  [realiz, attract, religion, asset, price, play...
# 4   2022-05-01 23:59:50  [ridicul, stock, bitcoin, money, liter, argume...
# 5   2022-05-01 23:59:48  [gignac, http, co, qdbqqc0gjq, http, co, rhxoc...
# 6   2022-05-01 23:59:48    [100trillionusd, bitcoin, http, co, rjka5xpoqh]
# 7   2022-05-01 23:59:48  [bitvolt7, bitcoin, take, crypto, cryptocurr, ...
# 8   2022-05-01 23:59:47  [outkastnft, se7enthdegen, gooneytoonsnft, nft...
# 9   2022-05-01 23:59:42  [nasrullahayan, benc, buffet, bu, konuda, geri...
# 10  2022-05-01 23:59:42  [memecoin, mad, round, 2, hpos10idotcom, vs, d...
# ...

# %%
final_bitcoin[['Datetime','Text']] = final_bitcoin.dates.str.split(" ",expand=True)

final_bitcoin
# Out:
#                      dates                                            cleaned  \
# 0      2022-05-01 23:59:56  [oh, think, im, pull, ass, bitcoin, http, co, ...
# 1      2022-05-01 23:59:56  [cryptic, oz, bitcoin, es, baloncesto, http, c...
# 2      2022-05-01 23:59:53  [un, long, sandbox, sandbox, crypto, bitcoin, ...
# 3      2022-05-01 23:59:52  [realiz, attract, religion, asset, price, play...
# 4      2022-05-01 23:59:50  [ridicul, stock, bitcoin, money, liter, argume...
# ...                    ...                                                ...
# 9996   2022-05-15 19:54:28  [wall, street, kurdu, kripto, kurslar, ki, ba,...
# 9997   2022-05-15 19:54:27  [huge, buy, power, kda, 72, hour, ago, explod,...
# 9998   2022-05-15 19:54:21  [educacionfinanciera, bitcoin, talk, crytocurr...
# 9999   2022-05-15 19:54:20  [analysi, may, 15th, current, price, btc, 3038...
# 10000  2022-05-15 19:54:20  [thejackforg, pay, bitcoin, send, case, white,...
#
# ...

# %%
final_bitcoin = final_bitcoin.filter(['Datetime', 'cleaned','negative','neutral','positive','comp'])
final_bitcoin.head(40)
# Out:
#       Datetime                                            cleaned  negative  \
# 0   2022-05-01  [oh, think, im, pull, ass, bitcoin, http, co, ...     0.304
# 1   2022-05-01  [cryptic, oz, bitcoin, es, baloncesto, http, c...     0.000
# 2   2022-05-01  [un, long, sandbox, sandbox, crypto, bitcoin, ...     0.000
# 3   2022-05-01  [realiz, attract, religion, asset, price, play...     0.000
# 4   2022-05-01  [ridicul, stock, bitcoin, money, liter, argume...     0.114
# 5   2022-05-01  [gignac, http, co, qdbqqc0gjq, http, co, rhxoc...     0.000
# 6   2022-05-01    [100trillionusd, bitcoin, http, co, rjka5xpoqh]     0.000
# 7   2022-05-01  [bitvolt7, bitcoin, take, crypto, cryptocurr, ...     0.000
# 8   2022-05-01  [outkastnft, se7enthdegen, gooneytoonsnft, nft...     0.000
# 9   2022-05-01  [nasrullahayan, benc, buffet, bu, konuda, geri...     0.000
# 10  2022-05-01  [memecoin, mad, round, 2, hpos10idotcom, vs, d...     0.158
# ...

# %%
final_bitcoin.to_csv('final_bitcoin.csv')
